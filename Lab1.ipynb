# %%
# Task 2:
import cv2
img = cv2.imread('images\dry-maple-leaves-grayscale.webp') #Load the
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
# task 2 b:
from PIL import Image
img2 = Image.open('images\grayscale-image.jpg')
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.imshow(img2, cmap = cm.Greys_r)
plt.show()

# %%
# task 3 a:
cv2.imwrite('images\pexels-nana-v-424998828-16114262.jpg', img)
# Out:
# True

# %%
# task 3 b:
img2.save('new_image2.jpg')

# %%
# task 4:
print(img.shape) #Note: img1 loaded using open cv is a numpy array
print(img)
# Out:
# (960, 640, 3)
# [[[217 217 217]
#   [217 217 217]
#   [217 217 217]
#   ...
#   [154 154 154]
#   [155 155 155]
#   [155 155 155]]
#
#  [[217 217 217]
#   [217 217 217]
#   [217 217 217]
#   ...
#   [150 150 150]
#   [150 150 150]
#   [150 150 150]]
#
#  [[217 217 217]
#   [217 217 217]
#   [217 217 217]
#   ...
#   [146 146 146]
#   [146 146 146]
#   [146 146 146]]
#
#  ...
#
#  [[184 184 184]
#   [185 185 185]
#   [187 187 187]
#   ...
#   [160 160 160]
#   [160 160 160]
#   [160 160 160]]
#
#  [[184 184 184]
#   [185 185 185]
#   [187 187 187]
#   ...
#   [156 156 156]
#   [156 156 156]
#   [156 156 156]]
#
#  [[184 184 184]
#   [185 185 185]
#   [187 187 187]
#   ...
#   [153 153 153]
#   [153 153 153]
#   [153 153 153]]]

# %%
import numpy as np
img_array = np.array(img2)
print(img_array.shape)
print(img_array)
# Out:
# (933, 1400, 3)
# [[[114 114 114]
#   [114 114 114]
#   [112 112 112]
#   ...
#   [161 161 161]
#   [159 159 159]
#   [159 159 159]]
#
#  [[114 114 114]
#   [116 116 116]
#   [116 116 116]
#   ...
#   [165 165 165]
#   [164 164 164]
#   [166 166 166]]
#
#  [[110 110 110]
#   [113 113 113]
#   [116 116 116]
#   ...
#   [163 163 163]
#   [164 164 164]
#   [167 167 167]]
#
#  ...
#
#  [[ 61  61  61]
#   [ 64  64  64]
#   [ 63  63  63]
#   ...
#   [212 212 212]
#   [213 213 213]
#   [213 213 213]]
#
#  [[ 61  61  61]
#   [ 65  65  65]
#   [ 64  64  64]
#   ...
#   [214 214 214]
#   [214 214 214]
#   [215 215 215]]
#
#  [[ 62  62  62]
#   [ 67  67  67]
#   [ 66  66  66]
#   ...
#   [215 215 215]
#   [216 216 216]
#   [216 216 216]]]
